# %% [markdown]
# ### import packs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import path
import PIL
from PIL import Image
import nltk
import string
import re
import random
from collections import Counter
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize 
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amiip\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### read in the file and filter what I want to use

# %%
ms = pd.read_csv("/Users/amiip/Desktop/2021W/PR_Erschliessung_mittelalterlicher_Musikhandschriften_der_OENB/A-Wn_1890.csv")

# %%
ms
# Out:
#          siglum marginalia folio  sequence  \
# 0     A-Wn 1890        NaN  001r         1
# 1     A-Wn 1890        NaN  001r         2
# 2     A-Wn 1890        NaN  001r         3
# 3     A-Wn 1890        NaN  001r         4
# 4     A-Wn 1890        NaN  001r         5
# 5     A-Wn 1890        NaN  001v         1
# 6     A-Wn 1890        NaN  001v         2
# 7     A-Wn 1890        NaN  001v         3
# 8     A-Wn 1890        NaN  001v         4
# 9     A-Wn 1890        NaN  001v         5
# 10    A-Wn 1890        NaN  001v         6
# 11    A-Wn 1890        NaN  001v         7
# 12    A-Wn 1890          R  002r         1
# 13    A-Wn 1890          R  002r         2
# 14    A-Wn 1890          R  002r         3
# 15    A-Wn 1890          R  002r         4
# 16    A-Wn 1890          R  002r         5
# 17    A-Wn 1890        NaN  002r         6
# 18    A-Wn 1890        NaN  002r         7
# 19    A-Wn 1890        NaN  002r         8
# 20    A-Wn 1890        NaN  002r         9
# 21    A-Wn 1890        NaN  002r        10
# 22    A-Wn 1890        NaN  002r        11
# 23    A-Wn 1890        NaN  002v         1
# 24    A-Wn 1890        NaN  002v         2
# 25    A-Wn 1890        NaN  002v         3
# 26    A-Wn 1890        NaN  002v         4
# 27    A-Wn 1890        NaN  002v         5
# 28    A-Wn 1890        NaN  002v         6
# 29    A-Wn 1890        NaN  002v         7
# ...         ...        ...   ...       ...
# 5546  A-Wn 1890        NaN  332r         6
# 5547  A-Wn 1890        NaN  332r         7
# 5548  A-Wn 1890        NaN  332r         8
# 5549  A-Wn 1890        NaN  332r         9
# 5550  A-Wn 1890        NaN  332r        10
# 5551  A-Wn 1890        NaN  332r        11
# 5552  A-Wn 1890        NaN  332r        12
# 5553  A-Wn 1890        NaN  332v         1
# 5554  A-Wn 1890        NaN  332v         2
# 5555  A-Wn 1890        NaN  332v         3
# 5556  A-Wn 1890        NaN  332v         4
# 5557  A-Wn 1890        NaN  332v         5
# 5558  A-Wn 1890        NaN  332v         6
# 5559  A-Wn 1890        NaN  332v         7
# 5560  A-Wn 1890        NaN  332v         8
# 5561  A-Wn 1890        NaN  332v         9
# 5562  A-Wn 1890        NaN  332v        10
# 5563  A-Wn 1890        NaN  333v         1
# 5564  A-Wn 1890        NaN  334r         1
# 5565  A-Wn 1890        NaN  334r         2
# 5566  A-Wn 1890        NaN  334r         3
# 5567  A-Wn 1890        NaN  334r         4
# 5568  A-Wn 1890        NaN  334r         5
# 5569  A-Wn 1890        NaN  334r         6
# 5570  A-Wn 1890        NaN  334v         1
# 5571  A-Wn 1890        NaN  334v         2
# 5572  A-Wn 1890        NaN  334v         3
# 5573  A-Wn 1890        NaN  334v         4
# 5574  A-Wn 1890        NaN  334v         5
# 5575  A-Wn 1890        NaN  334v         6
#
#                                              incipit            feast office  \
# 5566            Antequam comedam suspiro et tamquam            De Job      M
# 5567         Nolo multa fortitudine contendat mecum            De Job      M
# 5568        Utinam appenderentur peccata mea quibus            De Job      M
# 5569                Quasi harena maris haec gravior            De Job      M
# 5570      Quare detraxistis sermonibus veritatis ad            De Job      M
# 5571                 Militia est vita hominis super            De Job      M
# 5572                  Induta est caro mea putredine            De Job      M
# 5573             Dies mei sicut umbra declinaverunt            De Job      M
# 5574           Paucitas dierum meorum finitur brevi            De Job      M
# 5575                       Ecce in pulvere sedeo et            De Job      M
#
#      genre position cantus_id   ...   differentia_new  \
# 0        A        M    002527   ...               NaN
# 1        I      NaN    001149   ...               NaN
# 2        A       1.    003134   ...              211e
# 3        W       1.       NaN   ...               NaN
# 4        R      1.1    006129   ...               NaN
# 5        V       01   006129a   ...               NaN
# 6        V       02   006129b   ...               NaN
# 7        V       03   006129c   ...               NaN
# 8        R      1.2    006128   ...               NaN
# 9        V       01   006128a   ...               NaN
# 10       R      1.3    007170   ...               NaN
# 11       V       01   007170a   ...               NaN
# 12       W       1.    008060   ...               NaN
# 13       W       2.    008051   ...               NaN
# 14       W       3.    008043   ...               NaN
# 15       R      NaN    007728   ...               NaN
# 16       V       01   007728a   ...               NaN
# 17       R      1.4    007177   ...               NaN
# 18       V       01   007177a   ...               NaN
# 19       A       2.    003967   ...               34a
# 20       W       2.    008043   ...               NaN
# 21       R      2.1    006157   ...               NaN
# 22       V       01   006157b   ...               NaN
# 23       R      2.2    007562   ...               NaN
# 24       V       01   007562a   ...               NaN
# 25       R      2.3    006149   ...               NaN
# 26       V       01   006149a   ...               NaN
# 27       R      2.4    006066   ...               NaN
# 28       V       01   006066a   ...               NaN
# 29       A       3.    002201   ...              211a
# ...    ...      ...       ...   ...               ...
# 5546     V       01   007457a   ...               NaN
# 5547     R       12    007727   ...               NaN
# 5548     V       01   007727a   ...               NaN
# 5549     R       13    007204   ...               NaN
# 5550     V       01   007204a   ...               NaN
# 5551     R       14    006734   ...               NaN
# 5552     V       01   006734a   ...               NaN
# 5553     R       15    006140   ...               NaN
# 5554     V       01   006140a   ...               NaN
# 5555     A        1    004811   ...               NaN
# 5556     A        2    004810   ...              143c
# 5557     A        3    004153   ...              211e
# 5558     A        4    002576   ...               NaN
# 5559     A        5    004940   ...              153a
# 5560     A        6    002418   ...              123a
# 5561     A        7    004351   ...               NaN
# 5562     A        8    003662   ...               66r
# 5563     R        1    007143   ...               NaN
# 5564     R        2    007647   ...               NaN
# 5565     V       01   007647a   ...               NaN
# 5566     R        3    006106   ...               NaN
# 5567     V       01   006106a   ...               NaN
# 5568     R        4    007813   ...               NaN
# 5569     V       01   007813a   ...               NaN
# 5570     R        5    007463   ...               NaN
# 5571     V       01   007463a   ...               NaN
# 5572     R        6    006956   ...               NaN
# 5573     V       01   006956a   ...               NaN
# 5574     R        7    007367   ...               NaN
# 5575     V       01   007367a   ...               NaN
#
#                                   fulltext_standardized  \
# 0     Ecce nomen domini venit de longinquo et clarit...
# 1                Regem venturum dominum venite adoremus
# 2     Hora est jam nos de somno surgere et aperti su...
# 3                                                 -- --
# 3                                                   NaN      NaN
# 4     ASPICIENS a longe ecce video dei potentiam ven...      NaN
# 5     Quique terrigene et filii hominum simul in unu...      NaN
# 6     Qui regis israhel intende qui deducis velut ov...      NaN
# 7     Tollite portas principes vestras et elevamini ...      NaN
# 8     Aspiciebam in visu noctis et ecce in nubibus c...      NaN
# 9     Ecce dominator dominus cum virtute veniet | Et...      NaN
# 10    Missus est GabRiel angelus ad MaRiam virginem ...      NaN
# 11          Ave MaRia gratia plena dominus tecum | Ecce      NaN
# 12    Ex syon species decoris eius deus noster Manif...      NaN
# 13    Emitte Agnum domine dominatorem terre de petra...      NaN
# 14                Egredietur dominus de loco sancto suo      NaN
# 15                   Super te ierusalem orietur dominus      NaN
# 16                                                   Et      NaN
# 17    Montes israhel ramos vestros expandite et flor...      NaN
# 18    Rorate celi desuper et nubes pluant iustum ape...      NaN
# 19    Nox precessit dies autem adpropinquabit abicia...      NaN
# 20                Egredietur dominus De loco sancto suo      NaN
# 21    Ave MaRia gratia plena dominus tecum spiritus ...      NaN
# 22                    Tollite portas principes | Filius      NaN
# 23    Salvatorem expectamus dominum iesum xpictum qu...      NaN
# 24    Preoccupemus faciem eius in confessione et in ...      NaN
# 25    Audite verbum domini gentes et annuntiate illu...      NaN
# 26    A solis ortu et occasu ab aquilone et mari | E...      NaN
# 27    Alieni non transibunt per ierusalem amplius na...      NaN
# 28    Ego veniam dicit dominus et sanabo contricione...      NaN
# 29    Dicite filie syoN ecce Rex tuus veniet tibi sy...      NaN
# ...                                                 ...      ...
# 5546  Inperfectum meum viderunt oculi tui et in libr...      NaN
# 5547  Super salutem et omnem pulchritudinem dilexi s...      NaN
# 5548  Dixi sapientie soror mea es et prudentiam voca...      NaN
# 5549  Ne derelinquas me domine pater et dominator vi...      NaN
# 5550  Apprehende arma et scutum et exurge in adiutor...      NaN
# 5551  Fili noli deficere a disciplina domini et ne f...      NaN
# 5552  Audi fili mi disciplinam patris tui et ne dimi...      NaN
# 5553  Audi fili mi disciplinam patris tui et ne dimi...      NaN
# 5554  Honora dominum de tua substantia et de primiti...      NaN
# 5555  Sapientia clamitat in plateis si quis diligit ...      NaN
# 5556  Sapientia edificavit sibi domum excidit column...      NaN
# 5557  Omnis sapientia a domino deo est et cum illo f...      NaN
# 5558  Ego in altissimis habito et thronus meus in co...      NaN
# 5559  Sicut malum inter ligna silvarum sic dilectus ...      NaN
# 5560  Dominus possedit me initio viarum suarum anteq...      NaN
# 5561  Prebe fili cor tuum michi oculi tui videant eq...      NaN
# 5562  Magna enim sunt iudicia tua domine et inenarra...      NaN
# 5563                                   Memento mei deus      NaN
# 5564  Si bona suscepimus de manu domini mala autem q...      NaN
# 5565  In omnibus his non peccavit iob labiis suis ne...      NaN
# 5566  Antequam comedam suspiro et tamquam inundantes...      NaN
# 5567  Nolo multa fortitudine contendat mecum nec mag...      NaN
# 5568  Utinam appenderentur peccata mea quibus iram m...      NaN
# 5569  Quasi arena maris hec gravior apparet unde et ...      NaN
# 5570  Quare detraxistis sermonibus veritatis ad incr...      NaN
# 5571  Milicia est vita hominis super terram et sicut...      NaN
# 5572  Induta est caro mea putredine et sordibus pulv...      NaN
# 5573  Dies mei sicut umbra declinaverunt et ego sicu...      NaN
# 5574  Paucitas dierum meorum finitur brevi dimitte m...      NaN
# 5575  Ecce in pulvere sedeo et in pulvere dormio et ...      NaN
#
#                                              image_link melody_id  \
# 0     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 1     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 2     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 3     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 4     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 6     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 7     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 8     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 9     https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 10    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 11    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 12    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 13    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 14    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 15    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 16    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 17    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 18    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 19    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 20    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 21    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 22    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 23    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 24    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 25    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 26    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 27    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 28    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 29    https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# ...                                                 ...       ...
# 5546  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5547  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5548  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5549  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5550  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5551  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5552  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5553  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5554  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5555  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5556  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5557  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5558  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5559  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5560  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5561  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5562  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5563  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5564  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5565  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5566  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5567  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5568  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5569  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5570  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5571  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5572  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5573  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5574  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
# 5575  https://digital.onb.ac.at/RepViewer/viewer.fac...       NaN
#
#       cao_concordances addendum  extra node_id
# 0          CGBEMVHR FS      NaN    NaN  548587
# 1             CGBE VHR      NaN    NaN  548588
# 2               BE   R      NaN    NaN  548589
# 3                  NaN      NaN    NaN  548590
# 4           GBEMVHRDFS      NaN    NaN  548591
# 5           GBEMVHRDFS      NaN    NaN  548592
# 6            GBEMVHRDF      NaN    NaN  548593
# 7            BEMVHR  S      NaN    NaN  548594
# 8           GBEMVHRDFS      NaN    NaN  548595
# 9              BEM HRD      NaN    NaN  548596
# 10         GBEMVHRDFSL      NaN    NaN  548597
# 11             BEMVHRD      NaN    NaN  548598
# 12         C BE VHRDFS      NaN    NaN  548599
# 13        C  E    DFSL      NaN    NaN  548600
# 14         C BE VHRDFS      NaN    NaN  548601
# 15          GB  VHRDFS      NaN    NaN  548602
# 16          GB  VHRDFS      NaN    NaN  548603
# 17          BEMV RDFSL      NaN    NaN  548604
# 18          BEMV RDFSL      NaN    NaN  548605
# 19              BE   R      NaN    NaN  548606
# 20         C BE VHRDFS      NaN    NaN  548607
# 21         GBEMVHRDFSL      NaN    NaN  548608
# 22              B MVHR      NaN    NaN  548609
# 23          GBEMVHRDFS      NaN    NaN  548610
# 24              BEMVHR      NaN    NaN  548611
# 25          GBEMVHRDFS      NaN    NaN  548612
# 26              BEMVHR      NaN    NaN  548613
# 27            EMV RDFS      NaN    NaN  548614
# 28               V RDF      NaN    NaN  548615
# 29              BE  HR      NaN    NaN  548616
# ...                ...      ...    ...     ...
# 5546       C BE VHR FS      NaN    NaN  554128
# 5547      C BEMVHRDFSL      NaN    NaN  554129
# 5548        C BEMVHRDF      NaN    NaN  554130
# 5549      C BEMVHRDFSL      NaN    NaN  554131
# 5550      C BEMVHRDFSL      NaN    NaN  554132
# 5551        BE VHRDF L      NaN    NaN  554133
# 5552           BE VHRD      NaN    NaN  554134
# 5553        BE VHRDF L      NaN    NaN  554135
# 5554           BE VHRD      NaN    NaN  554136
# 5555       C BEMVHRDFS      NaN    NaN  554137
# 5556       C BEMVHRDFS      NaN    NaN  554138
# 5557      C BE VHRDFSL      NaN    NaN  554139
# 5558      C BE VHRDFSL      NaN    NaN  554140
# 5559         BE VHRD S      NaN      a  554141
# 5560      C BEMVHRDFSL      NaN    NaN  554142
# 5561                HR      NaN    NaN  554143
# 5562                HR      NaN    NaN  554144
# 5563      CGBEMVHRDFSL      NaN    NaN  554145
# 5564      CGBEMVHRDFSL      NaN    NaN  554146
# 5565      CGBEMVHRDF L      NaN    NaN  554147
# 5566      CGBEMVHRDFSL      NaN    NaN  554148
# 5567      CGBEMVHRDFSL      NaN    NaN  554149
# 5568       CGBEMVHRDFS      NaN    NaN  554150
# 5569       CGBEMVHRDFS      NaN    NaN  554151
# 5570      CGBEMVHRDFSL      NaN    NaN  554152
# 5571      CGB MVHRDF L      NaN    NaN  554153
# 5572      CGBEMVHRDFSL      NaN    NaN  554154
# 5573      CGBEMVHRD  L      NaN    NaN  554155
# 5574      CGBEMVHRDFSL      NaN    NaN  554156
# 5575       CGBEMVHRDFS      NaN    NaN  554157
#
# [5576 rows x 23 columns]

# %%
ms.dropna(axis="rows", subset=["fulltext_standardized"], inplace=True)
ms["fulltext_standardized"] += " "

texts = ms["fulltext_standardized"].sum()
#texts
print(len(texts))
# Out:
# 382042

# %%
#ms.info()

# %%
# filter chants: only Advent+Christmas (first Advent Sunday (=Dom. 1. Adventus) until 25.12.)
ms_adv = ms[1:511]
texts_adv = ms_adv["fulltext_standardized"].sum()
print(len(texts_adv))
# Out:
# 39737

# %%
# filter chants: only Lent/fasting period before Easter (Ash Wednesday until saturday before Easter Sunday)
ms_lent = ms[1928:2535]
texts_lent = ms_lent["fulltext_standardized"].sum()
print(len(texts_lent))
# Out:
# 52630

# %%
# filter chants: only Easter (Easter Sunday until before Whitsun)
ms_east = ms[2535:3264]
texts_east = ms_east["fulltext_standardized"].sum()
print(len(texts_east))
# Out:
# 44726

# %% [markdown]
# ### Clean texts and remove stop words:

# %%
cleaned_texts = texts.lower()
cleaned_texts = re.sub("\* ", "", cleaned_texts) # get rid of *
cleaned_texts = re.sub("\-", "", cleaned_texts) # get rid of -
cleaned_texts = re.sub(' +',' ', cleaned_texts) # get rid of multiple spaces
cleaned_texts = re.sub('\.','', cleaned_texts) # get rid of .
print(len(cleaned_texts))
#print(cleaned_texts)
# Out:
# 374663

# %%
stop_words = (["a","ab","ac","ad","at","atque","aut","autem","cum","de","dum","e","erant","erat","est","et","etiam",
"ex","haec","hic","hoc","in","ita","me","nec","neque","non","per","qua","quae","quam","qui","quibus","quidem","quo",
"quod","re","rebus","rem","res","sed","si","sic","sunt","tamen","tandem","te","ut","vel"])
# latin stopwords from https://github.com/WorldBrain/remove-stopwords

word_tokens = word_tokenize(cleaned_texts) 
    
filtered_list = [] 
for w in word_tokens: 
    if w not in stop_words: 
        filtered_list.append(w) 
#filtered_list

# %%
list_words = cleaned_texts.split()
list_words = [l.strip().lower() for l in filtered_list]

list_words[0:10]
# Out:
# ['ecce',
#  'nomen',
#  'domini',
#  'venit',
#  'longinquo',
#  'claritas',
#  'ejus',
#  'replet',
#  'orbem',
#  'terrarum']

# %% [markdown]
# ### Finding and counting occurences of words:

# %%
# Counting frequency of words
freqdist = Counter(list_words)
freqdist.most_common(10)
# Out:
# [('alleluia', 1174),
#  ('dominus', 521),
#  ('domine', 463),
#  ('ejus', 382),
#  ('deus', 346),
#  ('quia', 312),
#  ('dei', 296),
#  ('eum', 277),
#  ('domini', 224),
#  ('dominum', 220)]

# %%
count_alleluia = freqdist["alleluia"]
count_dominus = freqdist["dominus"]
#print(count_alleluia)
#print(count_dominus)

bar_all = [count_alleluia, count_dominus]
print(bar_all)
# Out:
# [1174, 521]

# %%
freqdist_adv = Counter(list_words_adv)
count_alleluia_adv = freqdist_adv["alleluia"]
count_dominus_adv = freqdist_adv["dominus"]
count_domine_adv = freqdist_adv["domine"]
count_deus_adv = freqdist_adv["deus"]
count_ejus_adv = freqdist_adv["ejus"]

bar_adv = [count_alleluia_adv, count_dominus_adv, count_domine_adv, count_deus_adv, count_ejus_adv]
print(bar_adv)
# Out:
# [66, 100, 33, 52, 59]

# %%
freqdist_lent = Counter(list_words_lent)
count_alleluia_lent = freqdist_lent["alleluia"]
count_dominus_lent = freqdist_lent["dominus"]
count_domine_lent = freqdist_lent["domine"]
count_deus_lent = freqdist_lent["deus"]
count_ejus_lent = freqdist_lent["ejus"]

bar_lent = [count_alleluia_lent, count_dominus_lent, count_domine_lent, count_deus_lent, count_ejus_lent]
print(bar_lent)
# Out:
# [0, 66, 98, 84, 49]

# %%
freqdist_east = Counter(list_words_east)
count_alleluia_east = freqdist_east["alleluia"]
count_dominus_east = freqdist_east["dominus"]
count_domine_east = freqdist_east["domine"]
count_deus_east = freqdist_east["deus"]
count_ejus_east = freqdist_east["ejus"]

bar_east = [count_alleluia_east, count_dominus_east, count_domine_east, count_deus_lent, count_ejus_east]
print(bar_east)
# Out:
# [829, 58, 35, 84, 32]

# %%
# finding occurances of one specific word, e.g. "alleluia"
expression = 'alleluia'

pos = 0 
positions = []

while pos != -1:
    position = cleaned_texts.find(expression,pos+1)
    pos = position
    positions.append(position)
positions.pop()

print('The expression is found {} times'.format(len(positions)))
#print(positions)
# Out:
# The expression is found 1174 times

# %%
# finding context around the word alleluia
tknzr = nltk.tokenize.WordPunctTokenizer()
tokens = tknzr.tokenize(cleaned_texts)
tokens = [token for token in tokens if token not in stop_words]
nltk_text = nltk.Text(tokens)

nltk_text.concordance(expression.lower(), width=60, lines=10)
# Out:
# Displaying 10 of 1174 matches:
# nem colles fluent lac mel alleluia jucundare filia sion exsu
# lta satis filia jerusalem alleluia ecce dominus veniet omnes
# o erit die illa lux magna alleluia omnes sitientes venientes
# e dominum inveniri potest alleluia ecce veniet propheta magn
#  ipse renovabit jerusalem alleluia super jerusalem orietur d
#  habebis utero filium dei alleluia sede dextris tu exsurgens
# e concipies paries filium alleluia regem venturum angelus do
# e concepit spiritu sancto alleluia venturus veniet tardabit
# lem respice orientem vide alleluia antequam convenirent inve
# ria habens spiritu sancto alleluia quaerite dominum inveniri

# %%
# words that often appear with alleluia in the same context
nltk_text.similar(expression)
# Out:
# r domine noster deus domino jam dominus caelo jesum ecce patre sion
# sancti suo super exaltare laetitia venit meum sanctus

# %% [markdown]
# ### Same for Advent, Lent and Easter:

# %%
cleaned_texts_adv = texts_adv.lower()
cleaned_texts_adv = re.sub("\* ", "", cleaned_texts_adv) # get rid of *
cleaned_texts_adv = re.sub("\-", "", cleaned_texts_adv) # get rid of -
cleaned_texts_adv = re.sub(' +',' ', cleaned_texts_adv) # get rid of multiple spaces
cleaned_texts_adv = re.sub('\.','', cleaned_texts_adv) # get rid of .

print(len(cleaned_texts_adv))
#print(cleaned_texts_adv)
# Out:
# 39112

# %%
cleaned_texts_lent = texts_lent.lower()
cleaned_texts_lent = re.sub("\* ", "", cleaned_texts_lent) # get rid of *
cleaned_texts_lent = re.sub("\-", "", cleaned_texts_lent) # get rid of -
cleaned_texts_lent = re.sub(' +',' ', cleaned_texts_lent) # get rid of multiple spaces
cleaned_texts_lent = re.sub('\.','', cleaned_texts_lent) # get rid of .

print(len(cleaned_texts_lent))
#print(cleaned_texts_lent)
# Out:
# 51956

# %%
cleaned_texts_east = texts_east.lower()
cleaned_texts_east = re.sub("\* ", "", cleaned_texts_east) # get rid of *
cleaned_texts_east = re.sub("\-", "", cleaned_texts_east) # get rid of -
cleaned_texts_east = re.sub(' +',' ', cleaned_texts_east) # get rid of multiple spaces
cleaned_texts_east = re.sub('\.','', cleaned_texts_east) # get rid of .

print(len(cleaned_texts_east))
#print(cleaned_texts_east)
# Out:
# 43680

# %%
word_tokens_adv = word_tokenize(cleaned_texts_adv) 
word_tokens_lent = word_tokenize(cleaned_texts_lent) 
word_tokens_east = word_tokenize(cleaned_texts_east) 
    
filtered_list_adv = [] 
for w in word_tokens_adv: 
    if w not in stop_words: 
        filtered_list_adv.append(w) 
filtered_list_lent = [] 
for w in word_tokens_lent: 
    if w not in stop_words: 
        filtered_list_lent.append(w) 
filtered_list_east = [] 
for w in word_tokens_east: 
    if w not in stop_words: 
        filtered_list_east.append(w) 
        
#filtered_list_adv
#filtered_list_lent
#filtered_list_east

# %%
list_words_adv = cleaned_texts_adv.split()
list_words_adv = [l.strip().lower() for l in filtered_list_adv]
list_words_lent = cleaned_texts_lent.split()
list_words_lent = [l.strip().lower() for l in filtered_list_lent]
list_words_east = cleaned_texts_east.split()
list_words_east = [l.strip().lower() for l in filtered_list_east]

#list_words_adv[0:10]
#list_words_lent[0:10]
#list_words_east[0:10]

# %%
# Counting frequency of words
freqdist_adv = Counter(list_words_adv)
freqdist_lent = Counter(list_words_lent)
freqdist_east = Counter(list_words_east)

#freqdist_adv.most_common(10)
#freqdist_lent.most_common(10)
freqdist_east.most_common(10)
# Out:
# [('alleluia', 829),
#  ('dominus', 58),
#  ('ego', 45),
#  ('eum', 40),
#  ('vobis', 39),
#  ('domine', 35),
#  ('quia', 33),
#  ('ejus', 32),
#  ('surrexit', 31),
#  ('sicut', 29)]

# %% [markdown]
# ## Trying to visualize my results

# %% [markdown]
# ### Barplots:

# %%
labels, values = zip(*freqdist.most_common(10))

indexes = np.arange(len(labels))
width = 0.5

plt.bar(indexes, values, width)
fig = plt.gcf()
fig.set_size_inches(10.5, 4)
plt.xticks(indexes + width * 0.05, labels)
plt.title("10 most frequent words in chants of A-Wn 1890", fontsize=18, color="royalblue")
plt.ylabel("No. of Occurences", fontweight="bold")
plt.show()

# %%
labels_adv, values_adv = zip(*freqdist_adv.most_common(10))

indexes_adv = np.arange(len(labels_adv))
width = 0.5

plt.bar(indexes_adv, values_adv, width, color="plum")
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.xticks(indexes_adv + width * 0.05, labels_adv)
plt.title("10 most frequent words in chants of A-Wn 1890 \nfor Advent", fontsize=18, color="purple")
plt.ylabel("No. of Occurences", fontweight="bold")
plt.show()

# %%
labels_lent, values_lent = zip(*freqdist_lent.most_common(10))
indexes_lent = np.arange(len(labels_lent))
width = 0.5

plt.bar(indexes_lent, values_lent, width, color="tomato")
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.xticks(indexes_lent + width * 0.05, labels_lent)
plt.title("10 most frequent words in chants of A-Wn 1890 \nfor Lent", fontsize=16, color="darkred")
plt.ylabel("No. of Occurences", fontweight="bold")
plt.show()

# %%
labels_east, values_east = zip(*freqdist_east.most_common(10))
indexes_east = np.arange(len(labels_east))
width = 0.5

plt.bar(indexes_east, values_east, width, color = "forestgreen", log=True)
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.xticks(indexes_east + width * 0.05, labels_east)
plt.title("10 most frequent words in chants of A-Wn 1890 \nfor Easter", fontsize=18, color="green")
plt.ylabel("No. of Occurences", fontweight="bold")
ax = plt.axes()
ax.set_facecolor("ivory")
plt.show()

# %%
# function for adding labels on the bars
def add_value_labels(ax, spacing=0):
    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + 0.1
        space = spacing
        label = "{:.0f}".format(y_value)
        ax.annotate(label, 
                    (x_value, y_value), 
                    xytext=(0, space), 
                    textcoords="offset points", 
                               va="bottom", 
                               ha="center")

# %%
labels = ["alleluia", "dominus", "domine", "deus", "ejus"]
barWidth = 0.25

#set position of bars on x axis
r1 = np.arange(len(bar_adv))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, bar_adv, color="#D0BDF0", width=barWidth, edgecolor="white", label="advent", log=True)
plt.bar(r2, bar_lent, color="#E66360", width=barWidth, edgecolor="white", label="lent", log=True)
plt.bar(r3, bar_east, color="#95C21B", width=barWidth, edgecolor="white", label="easter", log=True)

plt.title("Compairing word frequencies \nin chants of A-Wn 1890 for selected feasts", color="olivedrab", fontweight="bold")
plt.ylabel("Occurences \n", fontweight="bold")
plt.xticks([r + barWidth for r in range(len(bar_adv))], labels)
ax = plt.subplot()
ax.set_yticklabels([0, 0, 100])

add_value_labels(ax)
plt.legend(fancybox=True, shadow=True)
plt.show()

# %% [markdown]
# ### Wordclouds:

# %%
mask = np.array(Image.open("cross.png"))

cleaned = ' '.join(list_words)
wordcloud = WordCloud(max_words = 50, mask=mask, background_color="white", colormap="RdGy", contour_color="black", contour_width=1).generate(cleaned)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
cleaned = ' '.join(list_words_adv)
wordcloud = WordCloud(max_words = 50, background_color="white", colormap="RdGy").generate(cleaned)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
cleaned = ' '.join(list_words_lent)
wordcloud = WordCloud(max_words = 50, background_color="white", colormap="RdBu").generate(cleaned)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# it's noticable how the word alleluia isn't appearing as in all the other plots (since it's not a "happy" time for the church)

# %%
cleaned = ' '.join(list_words_east)
wordcloud = WordCloud(max_words = 50, background_color="white", colormap="RdBu").generate(cleaned)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
